# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
class NaiveBayes:
    
    def fit(self, x, y):
        n_samples, n_features = x.shape
        self._classes = np.unique(y)
        n_classes = len(self._classes)
        
        self._mean = np.zeros((n_classes, n_features), dtype=np.float64)
        self._var = np.zeros((n_classes, n_features), dtype=np.float64)
        self._priors = np.zeros(n_classes, dtype=np.float64)
        
        for idx,c in enumerate(self._classes):
            x_c = x[y==c]
            self._mean[idx,:] = x_c.mean(axis=0)
            self._var[idx,:] = x_c.var(axis=0)
            self._priors[idx] = x_c.shape[0]/ float(n_samples)
            
    def predict(self, x):
        y_predict = [self._predict(i) for i in x]
        return y_predict
    
    def _predict(self, x):
        posteriors = []
        
        for idx in range(len(self._classes)):
            prior = np.log(self._priors[idx])
            class_conditional = npsum(np.log(self.pdf(idx, x)))
            posterior = prior + class_conditional
            posteriors.append(posterior)
            
        return self._classes[np.argmax(posteriors)]
    
    def _pdf(self, class_idx, x):
        mean = self._mean[class_idx]
        var = self._var[class_idx]
        numerator = np.exp(- (x-mean)**2 / (2 * var))
        denominator = np.sqrt(2 * np.pi * var)
        return (numerator/denominator)

# %%
class StandardScaler(object):
    def __init__(self):
        pass
    
    def fit(self, X):
        self.mean_ = np.mean(X, axis=0)
        self.scale_ = np.std(X - self.mean_, axis=0)
        return self
    
    def transform(self, X):
        return (X - self.mean_) / self.scale_
    
    def fir_transform(self, X):
        return self.fit(X).transform(X)

# %%
df = pd.read_csv('data.csv')
df
# Out:
#      Umur    Gaji   Status Hutang Beli Laptop
# 0    <=30  tinggi   single  punya       tidak
# 1    <=30  tinggi   single  tidak       tidak
# 2   30-40  tinggi   single  punya         iya
# 3     >40  sedang   single  punya         iya
# 4     >40  rendah  menikah  punya         iya
# 5     >40  rendah  menikah  tidak       tidak
# 6   30-40  rendah  menikah  tidak         iya
# 7    <=30  sedang   single  punya       tidak
# 8    <=30  rendah  menikah  punya         iya
# 9     >40  sedang  menikah  punya         iya
# 10   <=30  sedang  menikah  tidak         iya
# 11  30-40  sedang   single  tidak         iya
# 12  30-40  tinggi  menikah  punya         iya
# 13    >40  sedang   single  tidak       tidak

# %%
s = StandardScaler()
df[['Umur', 'Gaji', 'Status', 'Hutang', 'Beli Laptop']]
print(s.mean_)
print(s.scale_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-eb6e115954e2> in <module>
#       1 s = StandardScaler()
#       2 df[['Umur', 'Gaji', 'Status', 'Hutang', 'Beli Laptop']]
# ----> 3 print(s.mean)
#       4 print(s.scale)
#
# AttributeError: 'StandardScaler' object has no attribute 'mean'

# %%
x = df[['Umur', 'Gaji', 'Status', 'Hutang']]
y = df['Beli Laptop']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 31)
x_test = np.array(x_test)
model = NaiveBayes()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
acc = accuracy_score(y_test, y_pred)
print('Accuracy: ', acc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-bda138b3ee37> in <module>
#       4 x_test = np.array(x_test)
#       5 model = NaiveBayes()
# ----> 6 model.fit(x_train,y_train)
#       7 y_pred = model.predict(x_test)
#       8 acc = accuracy_score(y_test, y_pred)
#
# <ipython-input-17-0f52b4a43b61> in fit(self, x, y)
#      11         for idx,c in enumerate(self._classes):
#      12             x_c = x[y==c]
# ---> 13             self._mean[idx,:] = x_c.mean(axis=0)
#      14             self._var[idx,:] = x_c.var(axis=0)
#      15             self._priors[idx] = x_c.shape[0]/float(n_samples)
#
# ValueError: could not broadcast input array from shape (0) into shape (4)
